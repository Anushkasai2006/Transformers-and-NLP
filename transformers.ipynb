# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
analayser = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
text_input=input("Enter the text : ")
# Out:
# Enter the text :

# %%
result=analayser(text_input)

# %%
result
# Out:
# [{'label': 'POSITIVE', 'score': 0.7481208443641663}]

# %%
generator = pipeline("text-generation")
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
statement=input("Enter any short statement:")
# Out:
# Enter any short statement:

# %%
result=generator(statement,max_length=150)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.

# %%
result
# Out:
# [{'generated_text': '3.75 mm thick, 15-12-1mm thick. Made in Slovenia.'}]

# %%
analayser = pipeline("ner")
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496 (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
text_input=input("Enter the text : ")
# Out:
# Enter the text :

# %%
result=analayser(text_input)

# %%
result
# Out:
# []

# %%
q_q=pipeline("question-answering")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
story_input = input("Enter your story: ")
# Out:
# Enter your story:

# %%
question_input = input("Enter your question: ")
# Out:
# Enter your question:

# %%
result = q_q(question=question_input, context=story_input)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-543a8186f68a> in <cell line: 0>()
# ----> 1 result = q_q(question=question_input, context=story_input)
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/question_answering.py in __call__(self, *args, **kwargs)
#     393             )
#     394
# --> 395         examples = self._args_parser(*args, **kwargs)
#     396         if isinstance(examples, (list, tuple)) and len(examples) == 1:
#     397             return super().__call__(examples[0], **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/question_answering.py in __call__(self, *args, **kwargs)
#     225
#     226         for i, item in enumerate(inputs):
# --> 227             inputs[i] = self.normalize(item)
#     228
#     229         return inputs
#
# ...

# %%
result

# %%
summarizwe=pipeline("summarization")

# %%
text_to_summarize = input("Enter the text to summarize: ")

# %%
result = summarizwe(text_to_summarize)

# %%
result

# %%
q_q=pipeline("question-answering")

# %%
context = """
Introducing the ZenBook X1, the latest in ultrabook innovation, designed for users who demand both performance and portability. This sleek, ultra-lightweight laptop features a 14-inch 4K OLED touchscreen display that offers vibrant colors and sharp contrast, perfect for creators, professionals, and casual users alike. Powered by the Intel Core i9-13th Gen processor, the ZenBook X1 delivers lightning-fast performance, whether you're multitasking, video editing, or running demanding applications.

Equipped with 16GB of DDR5 RAM and a 1TB NVMe SSD, the laptop ensures smooth and responsive operation, even when working with large files or multiple programs simultaneously. The battery life is impressive, providing up to 18 hours of continuous use on a single charge, thanks to its advanced 60Whr battery and power-efficient components.

The laptop's Thunderbolt 4 ports, Wi-Fi 6E, and Bluetooth 5.2 ensure fast data transfer and connectivity, whether you're working from home or on the go. The RGB-backlit keyboard adds a touch of personalization, while the precision touchpad offers seamless navigation.

For security, the ZenBook X1 features an IR camera for facial recognition and a fingerprint scanner, keeping your data safe without sacrificing convenience. The laptop's aluminum alloy chassis ensures both durability and a premium look, making it as stylish as it is functional. Weighing just 1.2kg (2.6 lbs), the ZenBook X1 is incredibly portable, perfect for professionals who are always on the move.

Whether you're a student, a remote worker, or a digital nomad, the ZenBook X1 is the ultimate companion for those seeking power, portability, and a high-end user experience
"""

print("Enter 'quit' to exit.")

while True:
  question = input("Ask a question: ")
  if question.lower() == 'quit':
    break
  answer = q_q(question=question, context=context)
  print(f"Answer: {answer['answer']}")

# %%
from transformers import pipeline

# %%
translator=pipeline("translation_en_to_fr")

# %%
text=input("Enter the text : ")

# %%
res=translator(text)

# %%
res

# %%
from transformers import pipeline

# %%
translator = pipeline("translation_en_to_de")

# %%
text_to_translate = input("Enter the English text to translate: ")

# %%
res=translator(text_to_translate)

# %%
res

# %%
f_m=pipeline("fill-mask")

# %%
text=input("enter a statement with a black having <mask>:")

# %%
res=f_m(text)

# %%
res

# %%
vqa_pipeline = pipeline("visual-question-answering")

# %%
image=r'/content/image.jpg.jpg'

# %%
question=input("Enter the question about the image:")

# %%
result=vqa_pipeline(image,question)
print(result)

# %%
# !pip install diffusers

# %%
from transformers import pipeline
import torch
from diffusers import DiffusionPipeline

# %%
generator=DiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4")

# %%
prompt='girl dancing'

# %%
image=generator(prompt).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
from tranformers import pipeline
t_g=pipeline("text-generation")

# %%
import time
from matplotlib import pyplot
data=[]
for _in range(5):
